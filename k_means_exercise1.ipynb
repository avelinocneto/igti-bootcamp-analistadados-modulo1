# %% [markdown]
# <a href="https://colab.research.google.com/github/avelinocneto/igti-bootcamp-analistadados-modulo1/blob/master/k_means_exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importação das biblioteca que serão utilizadas

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %% [markdown]
# ##  Exercícios 1 a 7 - Módulo 1

# %%
X, y = make_blobs(n_samples=500, centers=20, random_state=999)
plt.scatter(X[:,0], X[:,1])

# %%
wcss = []
s = 0
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,20), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=1, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(X)
kmeans.fit(X)

print('sum of wcss for 1 clusters')
print(kmeans.inertia_)
#write position for 1 cluster
print('')
print('position for 1 cluster')
print(kmeans.cluster_centers_[:,0])
print(kmeans.cluster_centers_[:,1])

#Draw graphic
#plt.scatter(X[:,0], X[:,1], c=pred_y)
#plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=50, c='red')
plt.show()


kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=0)
kmeans.fit(X)
print('')
print('sum of wcss for 5 clusters')
print(kmeans.inertia_)
# Out:
# sum of wcss for 1 clusters
# 31547.372471390485
#
# position for 1 cluster
# [0.02618523]
# [-1.30384304]
#
# sum of wcss for 5 clusters
# 4717.404091931214

# %%
import math  

def calculate_wcss(data):
    wcss = []
    for n in range(1, 20):
        kmeans = KMeans(n_clusters=n, init='k-means++', max_iter=300, n_init=10)
        kmeans.fit(X=data)
        wcss.append(kmeans.inertia_)

    return wcss

def optimal_number_of_clusters(wcss):
    x1, y1 = 2, wcss[0]
    x2, y2 = 20, wcss[len(wcss)-1]

    distances = []
    for i in range(len(wcss)):
        x0 = i+2
        y0 = wcss[i]
        numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominator = math.sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distances.append(numerator/denominator)
    
    return distances.index(max(distances)) + 2

ds = make_blobs(n_samples=500, centers=20, random_state=999)

# calculando a soma dos quadrados para as 19 quantidade de clusters
X = ds[0]
#sum_of_squares = calculate_wcss(X)
#print(sum_of_squares)
# calculando a quantidade ótima de clusters
soma = optimal_number_of_clusters(wcss)
print(soma)
# Out:
# [31547.372471390485, 16949.214472147927, 9464.847250570496, 6005.101775346179, 4717.404091931214, 3662.6403286096665, 2976.7808744471413, 2487.839596638861, 2049.8679429014373, 1841.8381644426468, 1648.3340466009743, 1496.9249614434852, 1307.0023641327027, 1165.6336477488371, 1072.1293113168324, 1004.4677591198649, 909.4876620392149, 855.2638567999431, 785.8718702434569]
# 5
